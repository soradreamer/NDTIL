# %% [markdown]
# - earlystopingを早める
# -

# %%
import pandas as pd
from ydata_profiling import ProfileReport
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import numpy as np
import seaborn as sns
# %matplotlib inline
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
test_df = pd.read_csv("test.csv")
train_df = pd.read_csv("train.csv")
weather = pd.read_csv("weather.csv")
sample = pd.read_csv("sample_submission.csv")

# %%
test_df
# Out:
#       kind      date      area
# 0     だいこん  20220502  千葉_各地_青森
# 1     だいこん  20220506  千葉_各地_青森
# 2     だいこん  20220507  千葉_各地_青森
# 3     だいこん  20220509  千葉_各地_青森
# 4     だいこん  20220510  千葉_各地_青森
# ..     ...       ...       ...
# 315  ミニトマト  20220526     各地_愛知
# 316  ミニトマト  20220527     各地_愛知
# 317  ミニトマト  20220528     各地_愛知
# 318  ミニトマト  20220530     各地_愛知
# 319  ミニトマト  20220531     各地_愛知
#
# [320 rows x 3 columns]

# %%
weather
# Out:
#             date  mean_temp  max_temp     max_temp_time  min_temp  \
# 0       20041106       13.1      20.1   2004/11/6 12:50       8.1
# 1       20041107        9.6      12.5   2004/11/7 13:40       5.4
# 2       20041108        9.0      15.5   2004/11/8 12:51       3.2
# 3       20041109       12.2      17.7   2004/11/9 14:40       5.7
# 4       20041110       11.6      16.4  2004/11/10 14:42       6.9
# ...          ...        ...       ...               ...       ...
# 204315  20220426       21.3      23.6   2022/4/26 14:27      17.9
# 204316  20220427       23.0      27.7   2022/4/27 13:12      18.9
# 204317  20220428       16.9      21.1   2022/4/28 15:03      14.2
# 204318  20220429       12.9      16.4   2022/4/29 09:21       9.0
# 204319  20220430       12.6      18.4   2022/4/30 14:49       7.4
#
#            min_temp_time  sum_rain  sun_time  mean_humid area
# 0        2004/11/6 05:31       5.0       1.6        77.0   青森
# 1        2004/11/7 22:17       0.0       4.1        63.0   青森
# 2        2004/11/8 06:28       0.0       8.9        72.0   青森
# 3        2004/11/9 02:49       1.5       1.2        85.0   青森
# 4       2004/11/10 06:23       0.0       7.5        89.0   青森
# ...                  ...       ...       ...         ...  ...
# 204315   2022/4/26 04:17       2.5       0.0        89.0   東京
# 204316    2022/4/28 0:00       0.5       1.6        79.0   東京
# 204317   2022/4/28 22:40       0.0       5.5        57.0   東京
# 204318   2022/4/29 23:55      40.0       0.2        86.0   東京
# 204319   2022/4/30 05:28       0.0      12.4        64.0   東京
#
# [204320 rows x 10 columns]

# %%
sample
# Out:
#       kind      date  mode_price
# 0     だいこん  20220502           0
# 1     だいこん  20220506           0
# 2     だいこん  20220507           0
# 3     だいこん  20220509           0
# 4     だいこん  20220510           0
# ..     ...       ...         ...
# 315  ミニトマト  20220526           0
# 316  ミニトマト  20220527           0
# 317  ミニトマト  20220528           0
# 318  ミニトマト  20220530           0
# 319  ミニトマト  20220531           0
#
# [320 rows x 3 columns]

# %%
#profile = ProfileReport(train_df, title="Profiling Report")
#profile.to_notebook_iframe()
#profile.to_file("your_report.html")
# amount削除
train_df = train_df.drop(columns=['amount'])

# %%
def Data_cre(df):
    # --- area を分解して複数行に展開 ---
    df["area_list"] = df["area"].str.split("_")

    # explodeで行を増やす
    df = df.explode("area_list")
    df = df.drop(columns=["area"])
    df = df.rename(columns={"area_list": "area"})

    # --- 日付フォーマット揃え ---
    df["date"] = df["date"].astype(str)
    df["date"] = pd.to_datetime(df["date"])

    # --- weather と結合 ---
    df = pd.merge(df, weather, on=["date", "area"], how="left")

    # --- 年月日列を追加 ---
    df["year"] = df["date"].dt.year
    df["month"] = df["date"].dt.month
    df["day"] = df["date"].dt.day

    # --- max_temp_time / min_temp_time 分解 ---
    df["max_temp_time"] = pd.to_datetime(df["max_temp_time"])
    df["maxtemp_year"] = df["max_temp_time"].dt.year
    df["maxtemp_month"] = df["max_temp_time"].dt.month
    df["maxtemp_day"] = df["max_temp_time"].dt.day
    df["maxtemp_hour"] = df["max_temp_time"].dt.hour

    df["min_temp_time"] = pd.to_datetime(df["min_temp_time"])
    df["mintemp_year"] = df["min_temp_time"].dt.year
    df["mintemp_month"] = df["min_temp_time"].dt.month
    df["mintemp_day"] = df["min_temp_time"].dt.day
    df["mintemp_hour"]= df["min_temp_time"].dt.hour

    # --- 不要列削除 ---
    df = df.drop(columns=["date", "max_temp_time", "min_temp_time"])

    # --- category 型に変換 ---
    df["kind"] = df["kind"].astype("category")
    df["area"] = df["area"].astype("category")

    return df
weather["date"] = pd.to_datetime(weather["date"])

train_df = Data_cre(train_df)

test_df = Data_cre(test_df)

# %%
train_df["area"]
# Out:
# 0         千葉
# 1         千葉
# 3         青森
# 4         千葉
# 6         青森
#           ..
# 212120    長野
# 212121    新潟
# 212122    長野
# 212123    新潟
# 212124    長野
# Name: area, Length: 153611, dtype: category
# Categories (39, object): ['アメリカ', 'カナダ', 'トンガ', 'ニュージーランド', ..., '静岡', '香川', '高知', '鹿児島']

# %%
train_df
# Out:
#         kind  mode_price area  mean_temp  max_temp  min_temp  sum_rain  \
# 0       だいこん       735.0   千葉        NaN       NaN       NaN       NaN
# 1       だいこん       840.0   千葉        NaN       NaN       NaN       NaN
# 3       だいこん       840.0   青森        NaN       NaN       NaN       NaN
# 4       だいこん       735.0   千葉        NaN       NaN       NaN       NaN
# 6       だいこん       735.0   青森        NaN       NaN       NaN       NaN
# ...      ...         ...  ...        ...       ...       ...       ...
# 212120   しめじ        48.5   長野        NaN       NaN       NaN       NaN
# 212121   しめじ        48.5   新潟        NaN       NaN       NaN       NaN
# 212122   しめじ        48.5   長野        NaN       NaN       NaN       NaN
# 212123   しめじ        43.0   新潟        NaN       NaN       NaN       NaN
# 212124   しめじ        43.0   長野        NaN       NaN       NaN       NaN
#
#         sun_time  mean_humid  year  month  day  maxtemp_year  maxtemp_month  \
# 0            NaN         NaN  2005     11    7           NaN            NaN
# 1            NaN         NaN  2005     11    8           NaN            NaN
# 3            NaN         NaN  2005     11    8           NaN            NaN
# 4            NaN         NaN  2005     11   10           NaN            NaN
# 6            NaN         NaN  2005     11   10           NaN            NaN
# ...          ...         ...   ...    ...  ...           ...            ...
# 212120       NaN         NaN  2017      5   29           NaN            NaN
# 212121       NaN         NaN  2017      5   30           NaN            NaN
# 212122       NaN         NaN  2017      5   30           NaN            NaN
# 212123       NaN         NaN  2017      5   31           NaN            NaN
# 212124       NaN         NaN  2017      5   31           NaN            NaN
#
#         maxtemp_day  maxtemp_hour  mintemp_year  mintemp_month  mintemp_day  \
# 0               NaN           NaN           NaN            NaN          NaN
# 1               NaN           NaN           NaN            NaN          NaN
# 3               NaN           NaN           NaN            NaN          NaN
# 4               NaN           NaN           NaN            NaN          NaN
# 6               NaN           NaN           NaN            NaN          NaN
# ...             ...           ...           ...            ...          ...
# 212120          NaN           NaN           NaN            NaN          NaN
# 212121          NaN           NaN           NaN            NaN          NaN
# 212122          NaN           NaN           NaN            NaN          NaN
# 212123          NaN           NaN           NaN            NaN          NaN
# 212124          NaN           NaN           NaN            NaN          NaN
#
#         mintemp_hour
# 0                NaN
# 1                NaN
# 3                NaN
# 4                NaN
# 6                NaN
# ...              ...
# 212120           NaN
# 212121           NaN
# 212122           NaN
# 212123           NaN
# 212124           NaN
#
# [153611 rows x 20 columns]

# %%
X = train_df.drop(['mode_price'], axis=1)
y = train_df['mode_price']
# 学習データとテストデータに分割
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=0)

# %%
### chatgpt
from sklearn.model_selection import KFold
import numpy as np
import lightgbm as lgb

models = {}  # kind → model list or averaged は辞書に保存

K = 5  # ← Fold数

for kd, group in train_df.groupby("kind", observed=False):

    print(f"\n===== {kd} モデルをKFold({K})で学習中 =====")

    X = group.drop(columns=["mode_price"],axis=1)
    y = group["mode_price"]

    kf = KFold(n_splits=K, shuffle=True, random_state=42)

    fold_models = []  # foldごとのモデルを保存

    for fold, (train_index, valid_index) in enumerate(kf.split(X)):
        print(f"Fold {fold+1}/{K}")

        X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
        y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]

        train_data = lgb.Dataset(X_train, y_train)
        valid_data = lgb.Dataset(X_valid, y_valid)

        params = {
            'objective': 'regression',
            'num_leaves': 5,
            'seed': fold,
            'verbose': -1,
        }

        model = lgb.train(
            params,
            train_data,
            num_boost_round=100,
            valid_sets=[train_data, valid_data],
            valid_names=['train', 'valid'],
            callbacks=[
                lgb.early_stopping(stopping_rounds=5, verbose=True),
                lgb.log_evaluation(50)
            ],
        )
        
        fold_models.append(model)

    models[kd] = fold_models  # kindごとにfoldモデルを保存
# Out:
# ===== いんげん モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 244248	valid's l2: 216094
# [100]	train's l2: 213991	valid's l2: 192004
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 213991	valid's l2: 192004
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 223063	valid's l2: 299687
# [100]	train's l2: 196539	valid's l2: 265698
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 196539	valid's l2: 265698
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 241171	valid's l2: 219463
# [100]	train's l2: 213443	valid's l2: 200644
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 213443	valid's l2: 200644
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 228943	valid's l2: 264004
# [100]	train's l2: 202852	valid's l2: 242538
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 202852	valid's l2: 242538
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 237133	valid's l2: 227602
# [100]	train's l2: 214624	valid's l2: 211777
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 214624	valid's l2: 211777
#
# ===== うど モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	train's l2: 137755	valid's l2: 233194
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	train's l2: 168111	valid's l2: 136688
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	train's l2: 147054	valid's l2: 194210
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	train's l2: 155847	valid's l2: 166512
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	train's l2: 165006	valid's l2: 119343
#
# ===== うめ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 619505	valid's l2: 692059
# Early stopping, best iteration is:
# [53]	train's l2: 608093	valid's l2: 688529
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 619693	valid's l2: 689420
# Early stopping, best iteration is:
# [83]	train's l2: 555124	valid's l2: 635961
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 639941	valid's l2: 638892
# Early stopping, best iteration is:
# [76]	train's l2: 570676	valid's l2: 586182
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 626741	valid's l2: 714588
# [100]	train's l2: 536395	valid's l2: 617784
# Early stopping, best iteration is:
# [95]	train's l2: 540305	valid's l2: 615871
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 617435	valid's l2: 765985
# [100]	train's l2: 525608	valid's l2: 652596
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 525608	valid's l2: 652596
#
# ===== えだまめ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 2489.3	valid's l2: 2544.5
# [100]	train's l2: 2217.35	valid's l2: 2314.12
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 2221.23	valid's l2: 2310.42
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 2600.05	valid's l2: 2096.85
# [100]	train's l2: 2316.72	valid's l2: 1855.21
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 2316.72	valid's l2: 1855.21
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 2386.33	valid's l2: 2773.34
# Early stopping, best iteration is:
# [70]	train's l2: 2243.81	valid's l2: 2666.46
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 2328.09	valid's l2: 3236.43
# [100]	train's l2: 2035.19	valid's l2: 2962.33
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 2035.19	valid's l2: 2962.33
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 2345.74	valid's l2: 2979.14
# Early stopping, best iteration is:
# [62]	train's l2: 2246.94	valid's l2: 2941.74
#
# ===== えのきだけ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [5]	train's l2: 9.58252	valid's l2: 2.06516
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 6.73365	valid's l2: 10.663
# [100]	train's l2: 6.69801	valid's l2: 10.3348
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 6.69801	valid's l2: 10.3348
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [13]	train's l2: 7.71254	valid's l2: 7.45826
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 7.77889	valid's l2: 7.19262
# [100]	train's l2: 7.74302	valid's l2: 6.93759
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 7.74302	valid's l2: 6.93759
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [10]	train's l2: 7.01804	valid's l2: 11.644
#
# ===== かぶ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 396.531	valid's l2: 453.256
# [100]	train's l2: 349.44	valid's l2: 408.431
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 349.44	valid's l2: 408.431
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 412.938	valid's l2: 384.751
# [100]	train's l2: 356.932	valid's l2: 351.759
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 356.932	valid's l2: 351.759
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 413.769	valid's l2: 389.091
# [100]	train's l2: 363.789	valid's l2: 347.906
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 363.789	valid's l2: 347.906
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 410.116	valid's l2: 406.764
# [100]	train's l2: 363.004	valid's l2: 368.539
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 363.004	valid's l2: 368.539
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 395.956	valid's l2: 457.375
# [100]	train's l2: 358.717	valid's l2: 407.356
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 358.717	valid's l2: 407.356
#
# ===== かぼちゃ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 499198	valid's l2: 481564
# [100]	train's l2: 443939	valid's l2: 429061
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 443939	valid's l2: 429061
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 498196	valid's l2: 496983
# [100]	train's l2: 449027	valid's l2: 451533
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 449027	valid's l2: 451533
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 491105	valid's l2: 529471
# [100]	train's l2: 433629	valid's l2: 479508
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 433629	valid's l2: 479508
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 494494	valid's l2: 521059
# [100]	train's l2: 436972	valid's l2: 476856
# Did not meet early stopping. Best iteration is:
# [97]	train's l2: 438222	valid's l2: 476798
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 496100	valid's l2: 502702
# [100]	train's l2: 445040	valid's l2: 448745
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 445040	valid's l2: 448745
#
# ===== きゅうり モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 171586	valid's l2: 209410
# [100]	train's l2: 152909	valid's l2: 187356
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 152909	valid's l2: 187356
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 175249	valid's l2: 192908
# [100]	train's l2: 155258	valid's l2: 173559
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 155258	valid's l2: 173559
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 178691	valid's l2: 177664
# [100]	train's l2: 158091	valid's l2: 160281
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 158091	valid's l2: 160281
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 181193	valid's l2: 160999
# [100]	train's l2: 161768	valid's l2: 145297
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 161768	valid's l2: 145297
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 180879	valid's l2: 164163
# [100]	train's l2: 161904	valid's l2: 153244
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 161904	valid's l2: 153244
#
# ===== こまつな モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 3476.66	valid's l2: 3514.87
# [100]	train's l2: 3018.08	valid's l2: 3132.45
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 3018.08	valid's l2: 3132.45
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 3466.4	valid's l2: 3265.35
# [100]	train's l2: 3030.98	valid's l2: 2891.24
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 3030.98	valid's l2: 2891.24
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 3543.94	valid's l2: 3002.94
# [100]	train's l2: 3214.68	valid's l2: 2672.89
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 3214.68	valid's l2: 2672.89
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 3462.21	valid's l2: 3591.57
# [100]	train's l2: 3000.82	valid's l2: 3160.07
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 3000.82	valid's l2: 3160.07
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 3227.05	valid's l2: 4213.4
# [100]	train's l2: 2848.65	valid's l2: 3808.98
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 2848.65	valid's l2: 3808.98
#
# ===== ごぼう モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 57671.6	valid's l2: 62276.5
# [100]	train's l2: 49791.1	valid's l2: 54371.9
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 49791.1	valid's l2: 54371.9
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 56375.5	valid's l2: 62687.5
# [100]	train's l2: 48564.3	valid's l2: 55420.6
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 48564.3	valid's l2: 55420.6
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 59122.8	valid's l2: 54835.8
# [100]	train's l2: 50473.6	valid's l2: 47396.1
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 50473.6	valid's l2: 47396.1
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 57517.1	valid's l2: 59855.2
# [100]	train's l2: 49436.2	valid's l2: 52411.8
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 49436.2	valid's l2: 52411.8
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 57828.4	valid's l2: 58006
# [100]	train's l2: 49408.4	valid's l2: 51124.2
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 49408.4	valid's l2: 51124.2
#
# ===== さつまいも モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 66626.1	valid's l2: 63581
# [100]	train's l2: 59861.9	valid's l2: 59112.7
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 59861.9	valid's l2: 59112.7
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 65374	valid's l2: 69807
# [100]	train's l2: 59555.7	valid's l2: 64084.3
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 59555.7	valid's l2: 64084.3
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 64544	valid's l2: 75905.2
# [100]	train's l2: 58504.6	valid's l2: 70075.5
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 58504.6	valid's l2: 70075.5
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 67417	valid's l2: 62184.1
# [100]	train's l2: 61284.4	valid's l2: 56807
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 61284.4	valid's l2: 56807
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 66609.9	valid's l2: 66112.9
# [100]	train's l2: 60436.4	valid's l2: 61683.6
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 60436.4	valid's l2: 61683.6
#
# ===== さといも モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 592110	valid's l2: 680273
# [100]	train's l2: 551119	valid's l2: 646377
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 551119	valid's l2: 646377
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 604715	valid's l2: 620796
# Early stopping, best iteration is:
# [57]	train's l2: 599808	valid's l2: 618888
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 600156	valid's l2: 635263
# Early stopping, best iteration is:
# [80]	train's l2: 568678	valid's l2: 614300
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 609547	valid's l2: 593141
# [100]	train's l2: 570570	valid's l2: 572759
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 571354	valid's l2: 572551
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 602898	valid's l2: 655641
# Early stopping, best iteration is:
# [60]	train's l2: 594569	valid's l2: 651347
#
# ===== さやえんどう モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [29]	train's l2: 124358	valid's l2: 169175
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 121359	valid's l2: 131092
# [100]	train's l2: 104765	valid's l2: 114901
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 104765	valid's l2: 114901
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 110639	valid's l2: 193836
# Early stopping, best iteration is:
# [83]	train's l2: 100067	valid's l2: 182000
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [21]	train's l2: 136858	valid's l2: 199920
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 130091	valid's l2: 90433.8
# Early stopping, best iteration is:
# [80]	train's l2: 118461	valid's l2: 82482.2
#
# ===== しめじ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	train's l2: 3.13388	valid's l2: 0.551837
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	train's l2: 3.13388	valid's l2: 0.551837
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	train's l2: 2.42776	valid's l2: 3.20399
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	train's l2: 1.7049	valid's l2: 6.23161
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1]	train's l2: 2.41879	valid's l2: 3.32253
#
# ===== しゅんぎく モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 451.103	valid's l2: 487.24
# [100]	train's l2: 334.682	valid's l2: 384.365
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 334.682	valid's l2: 384.365
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 449.531	valid's l2: 503.278
# [100]	train's l2: 313.594	valid's l2: 363.988
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 313.594	valid's l2: 363.988
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 457.824	valid's l2: 454.907
# [100]	train's l2: 329.266	valid's l2: 357.546
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 329.266	valid's l2: 357.546
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 440.083	valid's l2: 497.49
# [100]	train's l2: 318.327	valid's l2: 374.924
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 318.327	valid's l2: 374.924
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 448.129	valid's l2: 536.38
# [100]	train's l2: 335.523	valid's l2: 397.257
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 336.078	valid's l2: 396.87
#
# ===== じゃがいも モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 165526	valid's l2: 164390
# [100]	train's l2: 137756	valid's l2: 141392
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 137756	valid's l2: 141392
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 165980	valid's l2: 162558
# [100]	train's l2: 135028	valid's l2: 138290
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 135028	valid's l2: 138290
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 164161	valid's l2: 164438
# [100]	train's l2: 137590	valid's l2: 137041
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 137590	valid's l2: 137041
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 162951	valid's l2: 178317
# [100]	train's l2: 134421	valid's l2: 148564
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 134421	valid's l2: 148564
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 163576	valid's l2: 165512
# [100]	train's l2: 137145	valid's l2: 136205
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 137145	valid's l2: 136205
#
# ===== そらまめ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 246803	valid's l2: 286421
# [100]	train's l2: 225370	valid's l2: 276154
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 225370	valid's l2: 276154
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 243047	valid's l2: 274725
# Early stopping, best iteration is:
# [69]	train's l2: 231546	valid's l2: 270760
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 254095	valid's l2: 247801
# [100]	train's l2: 228607	valid's l2: 231328
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 228607	valid's l2: 231328
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [36]	train's l2: 255495	valid's l2: 265470
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 248162	valid's l2: 268412
# Early stopping, best iteration is:
# [79]	train's l2: 233639	valid's l2: 257878
#
# ===== たけのこ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 460061	valid's l2: 677480
# [100]	train's l2: 362286	valid's l2: 616283
# Did not meet early stopping. Best iteration is:
# [98]	train's l2: 364765	valid's l2: 612372
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 475910	valid's l2: 582243
# [100]	train's l2: 387603	valid's l2: 491720
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 387603	valid's l2: 491720
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 509589	valid's l2: 441543
# Early stopping, best iteration is:
# [60]	train's l2: 483229	valid's l2: 426017
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 411817	valid's l2: 595470
# [100]	train's l2: 314264	valid's l2: 496705
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 314264	valid's l2: 496705
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 491460	valid's l2: 539996
# [100]	train's l2: 396116	valid's l2: 460514
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 396987	valid's l2: 460053
#
# ===== たまねぎ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 269652	valid's l2: 307006
# [100]	train's l2: 192599	valid's l2: 211850
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 192599	valid's l2: 211850
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 256124	valid's l2: 251222
# [100]	train's l2: 190757	valid's l2: 189753
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 190757	valid's l2: 189753
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 264288	valid's l2: 262299
# [100]	train's l2: 194179	valid's l2: 189515
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 194179	valid's l2: 189515
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 264626	valid's l2: 245724
# [100]	train's l2: 192198	valid's l2: 184665
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 192198	valid's l2: 184665
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 255589	valid's l2: 286265
# [100]	train's l2: 190332	valid's l2: 218117
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 190332	valid's l2: 218117
#
# ===== だいこん モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 55188.5	valid's l2: 53204.6
# [100]	train's l2: 48457.4	valid's l2: 47151
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 48457.4	valid's l2: 47151
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 54384.9	valid's l2: 56027.5
# [100]	train's l2: 46974.7	valid's l2: 49386.9
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 46974.7	valid's l2: 49386.9
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 54758.2	valid's l2: 58789.2
# [100]	train's l2: 47666.1	valid's l2: 52224.7
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 47666.1	valid's l2: 52224.7
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 55060.4	valid's l2: 55061.5
# [100]	train's l2: 48329.8	valid's l2: 48056.9
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 48329.8	valid's l2: 48056.9
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 55132.3	valid's l2: 56135.2
# [100]	train's l2: 47639.8	valid's l2: 48790.4
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 47639.8	valid's l2: 48790.4
#
# ===== とうもろこし モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 42667.5	valid's l2: 49242.9
# [100]	train's l2: 37716.3	valid's l2: 45632.9
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 37716.3	valid's l2: 45632.9
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 43360.9	valid's l2: 47996.6
# [100]	train's l2: 38708.8	valid's l2: 44156.3
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 38708.8	valid's l2: 44156.3
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 43988.1	valid's l2: 45259
# [100]	train's l2: 38205.5	valid's l2: 42296.6
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 38205.5	valid's l2: 42296.6
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 43753.8	valid's l2: 45807.7
# Early stopping, best iteration is:
# [79]	train's l2: 40592.9	valid's l2: 43974.7
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 44804.9	valid's l2: 46444.4
# [100]	train's l2: 40187	valid's l2: 42126.1
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 40187	valid's l2: 42126.1
#
# ===== なす モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 141338	valid's l2: 151064
# [100]	train's l2: 126978	valid's l2: 135455
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 126978	valid's l2: 135455
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 141856	valid's l2: 138470
# [100]	train's l2: 125368	valid's l2: 125648
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 125368	valid's l2: 125648
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 140175	valid's l2: 144598
# [100]	train's l2: 125674	valid's l2: 132704
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 125674	valid's l2: 132704
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 141256	valid's l2: 143569
# [100]	train's l2: 124673	valid's l2: 133251
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 124673	valid's l2: 133251
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 139422	valid's l2: 146533
# [100]	train's l2: 123525	valid's l2: 133293
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 123525	valid's l2: 133293
#
# ===== なのはな モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 1113.92	valid's l2: 1472.91
# [100]	train's l2: 1001.27	valid's l2: 1406.67
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 1001.27	valid's l2: 1406.67
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 1077.5	valid's l2: 1712.41
# [100]	train's l2: 978.826	valid's l2: 1613.99
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 978.826	valid's l2: 1613.99
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 1157.76	valid's l2: 1253.61
# Early stopping, best iteration is:
# [84]	train's l2: 1059.17	valid's l2: 1201.78
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 1137.16	valid's l2: 1257
# Early stopping, best iteration is:
# [67]	train's l2: 1085.15	valid's l2: 1208.24
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 1176.53	valid's l2: 1172.13
# Early stopping, best iteration is:
# [46]	train's l2: 1193.88	valid's l2: 1170.07
#
# ===== なましいたけ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 176.603	valid's l2: 170.711
# [100]	train's l2: 132.392	valid's l2: 132.427
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 132.392	valid's l2: 132.427
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 182.975	valid's l2: 198.595
# [100]	train's l2: 133.687	valid's l2: 149.52
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 133.687	valid's l2: 149.52
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 176.429	valid's l2: 167.605
# [100]	train's l2: 134.084	valid's l2: 128.121
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 134.084	valid's l2: 128.121
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 175.921	valid's l2: 206.188
# [100]	train's l2: 130.374	valid's l2: 156.563
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 130.374	valid's l2: 156.563
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 178.694	valid's l2: 166.056
# [100]	train's l2: 134.338	valid's l2: 127.303
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 134.338	valid's l2: 127.303
#
# ===== にら モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [25]	train's l2: 102.541	valid's l2: 103.095
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [34]	train's l2: 93.7751	valid's l2: 110.507
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 93.7169	valid's l2: 93.6449
# Early stopping, best iteration is:
# [49]	train's l2: 93.9798	valid's l2: 93.2538
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 89.265	valid's l2: 97.7044
# Early stopping, best iteration is:
# [47]	train's l2: 89.9972	valid's l2: 96.6378
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [34]	train's l2: 84.463	valid's l2: 145.798
#
# ===== にんじん モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 160438	valid's l2: 150354
# [100]	train's l2: 133389	valid's l2: 124389
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 133389	valid's l2: 124389
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 154987	valid's l2: 163930
# [100]	train's l2: 125136	valid's l2: 136290
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 125136	valid's l2: 136290
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 156757	valid's l2: 157147
# [100]	train's l2: 130913	valid's l2: 134388
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 130913	valid's l2: 134388
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 155846	valid's l2: 174233
# [100]	train's l2: 126983	valid's l2: 139303
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 126983	valid's l2: 139303
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 159355	valid's l2: 157916
# [100]	train's l2: 128788	valid's l2: 131819
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 128788	valid's l2: 131819
#
# ===== ねぎ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 149903	valid's l2: 169017
# [100]	train's l2: 126570	valid's l2: 148574
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 126570	valid's l2: 148574
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 157925	valid's l2: 133638
# [100]	train's l2: 133911	valid's l2: 112084
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 133911	valid's l2: 112084
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 156937	valid's l2: 148183
# [100]	train's l2: 133272	valid's l2: 125512
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 133272	valid's l2: 125512
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 152332	valid's l2: 175636
# [100]	train's l2: 125942	valid's l2: 146368
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 125942	valid's l2: 146368
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 154390	valid's l2: 157119
# [100]	train's l2: 130360	valid's l2: 133041
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 130360	valid's l2: 133041
#
# ===== はくさい モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 145770	valid's l2: 140523
# [100]	train's l2: 126536	valid's l2: 123807
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 126536	valid's l2: 123807
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 148633	valid's l2: 144875
# [100]	train's l2: 130694	valid's l2: 127615
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 130694	valid's l2: 127615
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 149062	valid's l2: 142342
# [100]	train's l2: 130066	valid's l2: 123695
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 130066	valid's l2: 123695
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 146762	valid's l2: 152911
# [100]	train's l2: 127071	valid's l2: 134430
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 127071	valid's l2: 134430
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 142332	valid's l2: 165898
# [100]	train's l2: 123368	valid's l2: 148857
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 123368	valid's l2: 148857
#
# ===== ふき モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 19252.5	valid's l2: 19249.4
# [100]	train's l2: 16439.9	valid's l2: 17423
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 16439.9	valid's l2: 17423
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 19068.8	valid's l2: 22055
# [100]	train's l2: 16519.9	valid's l2: 19775.3
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 16519.9	valid's l2: 19775.3
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 19264.2	valid's l2: 18923.5
# [100]	train's l2: 16544.8	valid's l2: 17560.4
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 16607.1	valid's l2: 17554.8
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 18911.6	valid's l2: 24881
# [100]	train's l2: 16433.7	valid's l2: 21776.1
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 16433.7	valid's l2: 21776.1
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 19290.4	valid's l2: 20928.7
# [100]	train's l2: 16749.4	valid's l2: 19363.7
# Did not meet early stopping. Best iteration is:
# [98]	train's l2: 16817	valid's l2: 19334.6
#
# ===== ほうれんそう モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 678.749	valid's l2: 656.63
# [100]	train's l2: 589.502	valid's l2: 578.347
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 589.502	valid's l2: 578.347
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 663.491	valid's l2: 710.575
# [100]	train's l2: 585.795	valid's l2: 630.676
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 585.795	valid's l2: 630.676
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 677.362	valid's l2: 707.533
# [100]	train's l2: 600.087	valid's l2: 632.485
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 600.087	valid's l2: 632.485
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 677.817	valid's l2: 655.639
# [100]	train's l2: 593.98	valid's l2: 584.991
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 593.98	valid's l2: 584.991
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 663.796	valid's l2: 699.956
# [100]	train's l2: 582.534	valid's l2: 620.571
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 582.534	valid's l2: 620.571
#
# ===== まつたけ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 8.44721e+06	valid's l2: 1.06578e+07
# [100]	train's l2: 6.8373e+06	valid's l2: 9.19607e+06
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 6.8373e+06	valid's l2: 9.19607e+06
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 8.40527e+06	valid's l2: 1.04411e+07
# [100]	train's l2: 6.64139e+06	valid's l2: 8.59162e+06
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 6.64139e+06	valid's l2: 8.59162e+06
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 8.91889e+06	valid's l2: 8.7802e+06
# [100]	train's l2: 6.99883e+06	valid's l2: 7.11117e+06
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 6.99883e+06	valid's l2: 7.11117e+06
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 8.53015e+06	valid's l2: 8.83335e+06
# [100]	train's l2: 7.0389e+06	valid's l2: 7.3392e+06
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 7.0389e+06	valid's l2: 7.3392e+06
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 8.01653e+06	valid's l2: 1.06545e+07
# [100]	train's l2: 6.24409e+06	valid's l2: 9.81775e+06
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 6.24409e+06	valid's l2: 9.81775e+06
#
# ===== みずな モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 233.212	valid's l2: 284.479
# Early stopping, best iteration is:
# [59]	train's l2: 222.923	valid's l2: 280.339
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 252.671	valid's l2: 190.293
# [100]	train's l2: 224.29	valid's l2: 178.443
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 224.553	valid's l2: 178.393
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 218.695	valid's l2: 386.616
# [100]	train's l2: 188.552	valid's l2: 346.564
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 188.552	valid's l2: 346.564
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 247.824	valid's l2: 182.866
# Early stopping, best iteration is:
# [77]	train's l2: 215.921	valid's l2: 160.619
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 233.8	valid's l2: 305.646
# Early stopping, best iteration is:
# [70]	train's l2: 217.049	valid's l2: 287.345
#
# ===== れんこん モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 25357.6	valid's l2: 29816.9
# [100]	train's l2: 20393.6	valid's l2: 24869.3
# Did not meet early stopping. Best iteration is:
# [98]	train's l2: 20453.2	valid's l2: 24826.5
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 24412.7	valid's l2: 31762.3
# [100]	train's l2: 19507	valid's l2: 27414.7
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 19507	valid's l2: 27414.7
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 26113.7	valid's l2: 27405.7
# [100]	train's l2: 21461.5	valid's l2: 23618.1
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 21461.5	valid's l2: 23618.1
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 25835.7	valid's l2: 22360.2
# [100]	train's l2: 21301.2	valid's l2: 18785.2
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 21301.2	valid's l2: 18785.2
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 25693.1	valid's l2: 33910.8
# [100]	train's l2: 20570.7	valid's l2: 28327.9
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 20570.7	valid's l2: 28327.9
#
# ===== アスパラガス モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 142.415	valid's l2: 181.491
# [100]	train's l2: 118.036	valid's l2: 156.618
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 118.036	valid's l2: 156.618
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 133.953	valid's l2: 191.066
# Early stopping, best iteration is:
# [64]	train's l2: 125.876	valid's l2: 182.266
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 145.539	valid's l2: 216.284
# [100]	train's l2: 114.8	valid's l2: 186.341
# Did not meet early stopping. Best iteration is:
# [98]	train's l2: 115.624	valid's l2: 185.568
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 144.659	valid's l2: 149.144
# Early stopping, best iteration is:
# [49]	train's l2: 145.722	valid's l2: 148.309
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 147.52	valid's l2: 162.873
# [100]	train's l2: 122.699	valid's l2: 133.114
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 122.699	valid's l2: 133.114
#
# ===== オクラ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 162.514	valid's l2: 111.329
# [100]	train's l2: 131.365	valid's l2: 97.3845
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 131.83	valid's l2: 97.3248
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 150.334	valid's l2: 156.284
# Early stopping, best iteration is:
# [59]	train's l2: 143.529	valid's l2: 151.237
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 137.022	valid's l2: 246.88
# [100]	train's l2: 109.031	valid's l2: 219.457
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 109.031	valid's l2: 219.457
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 144.92	valid's l2: 206.394
# Early stopping, best iteration is:
# [72]	train's l2: 129.959	valid's l2: 196.601
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [44]	train's l2: 155.068	valid's l2: 176.477
#
# ===== キャベツ モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 93898.6	valid's l2: 93762.4
# [100]	train's l2: 79878.9	valid's l2: 79782.6
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 79878.9	valid's l2: 79782.6
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 92833.8	valid's l2: 96393.5
# [100]	train's l2: 79700.2	valid's l2: 82848.8
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 79700.2	valid's l2: 82848.8
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 94550.8	valid's l2: 102820
# [100]	train's l2: 79401.1	valid's l2: 86263.4
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 79401.1	valid's l2: 86263.4
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 95704.5	valid's l2: 91210.6
# [100]	train's l2: 78039.5	valid's l2: 77177.5
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 78039.5	valid's l2: 77177.5
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 93298	valid's l2: 92991.1
# [100]	train's l2: 78595.4	valid's l2: 78577.7
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 78595.4	valid's l2: 78577.7
#
# ===== セルリー モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 154683	valid's l2: 168834
# [100]	train's l2: 132455	valid's l2: 151855
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 132455	valid's l2: 151855
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 158979	valid's l2: 164353
# [100]	train's l2: 137230	valid's l2: 144131
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 137230	valid's l2: 144131
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 160913	valid's l2: 145343
# [100]	train's l2: 137946	valid's l2: 129444
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 137946	valid's l2: 129444
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 159156	valid's l2: 152212
# [100]	train's l2: 136333	valid's l2: 135738
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 136333	valid's l2: 135738
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 153198	valid's l2: 186757
# [100]	train's l2: 133128	valid's l2: 158567
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 133128	valid's l2: 158567
#
# ===== トマト モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 92338.8	valid's l2: 101227
# [100]	train's l2: 78484.3	valid's l2: 88190
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 78484.3	valid's l2: 88190
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 93731.8	valid's l2: 95993.2
# [100]	train's l2: 80354	valid's l2: 82342.8
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 80354	valid's l2: 82342.8
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 94952.6	valid's l2: 93799
# [100]	train's l2: 78861.8	valid's l2: 79052.2
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 79047.3	valid's l2: 79029.2
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 97238.7	valid's l2: 88240.4
# [100]	train's l2: 81837.2	valid's l2: 75684.1
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 81837.2	valid's l2: 75684.1
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 92633.3	valid's l2: 98895.2
# [100]	train's l2: 78663.4	valid's l2: 84032.3
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 78663.4	valid's l2: 84032.3
#
# ===== ピース モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 157518	valid's l2: 128759
# [100]	train's l2: 126458	valid's l2: 106279
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 126458	valid's l2: 106279
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 147383	valid's l2: 154248
# Early stopping, best iteration is:
# [56]	train's l2: 141658	valid's l2: 153192
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 120194	valid's l2: 205037
# Early stopping, best iteration is:
# [52]	train's l2: 118861	valid's l2: 204972
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 128704	valid's l2: 172937
# [100]	train's l2: 105883	valid's l2: 144848
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 105883	valid's l2: 144848
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 140548	valid's l2: 210741
# [100]	train's l2: 117052	valid's l2: 167857
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 117387	valid's l2: 167636
#
# ===== ピーマン モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 258.351	valid's l2: 288.607
# [100]	train's l2: 224.755	valid's l2: 249.983
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 224.755	valid's l2: 249.983
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 260.657	valid's l2: 274.112
# [100]	train's l2: 226.284	valid's l2: 243.134
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 226.284	valid's l2: 243.134
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 267.165	valid's l2: 245.551
# [100]	train's l2: 234.165	valid's l2: 218.962
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 234.165	valid's l2: 218.962
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 261.208	valid's l2: 271.851
# [100]	train's l2: 229.266	valid's l2: 245.054
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 229.266	valid's l2: 245.054
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 264.42	valid's l2: 252.27
# [100]	train's l2: 231.554	valid's l2: 223.126
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 231.554	valid's l2: 223.126
#
# ===== ブロッコリー モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 100416	valid's l2: 107220
# [100]	train's l2: 85323	valid's l2: 93227.4
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 85323	valid's l2: 93227.4
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 93193.7	valid's l2: 132359
# [100]	train's l2: 77202.6	valid's l2: 117631
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 77345.7	valid's l2: 117525
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 97596	valid's l2: 112812
# [100]	train's l2: 80218	valid's l2: 97851.2
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 80319.3	valid's l2: 97711.4
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 98208.5	valid's l2: 116541
# [100]	train's l2: 84925.5	valid's l2: 107062
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 84925.5	valid's l2: 107062
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 103898	valid's l2: 73888.1
# Early stopping, best iteration is:
# [88]	train's l2: 88589.6	valid's l2: 68426.4
#
# ===== ミニトマト モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 529.773	valid's l2: 505.541
# [100]	train's l2: 445.947	valid's l2: 443.546
# Did not meet early stopping. Best iteration is:
# [99]	train's l2: 447.216	valid's l2: 443.207
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 538.817	valid's l2: 456.8
# [100]	train's l2: 455.224	valid's l2: 388.678
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 455.224	valid's l2: 388.678
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 540.033	valid's l2: 446.326
# [100]	train's l2: 464.798	valid's l2: 396.345
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 464.798	valid's l2: 396.345
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 543.308	valid's l2: 422.814
# [100]	train's l2: 466.606	valid's l2: 354.968
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 466.606	valid's l2: 354.968
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 421.972	valid's l2: 925.248
# [100]	train's l2: 346.866	valid's l2: 855.829
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 346.866	valid's l2: 855.829
#
# ===== レイシにがうり モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 21099.1	valid's l2: 36044.9
# [100]	train's l2: 16806.8	valid's l2: 32683.3
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 16806.8	valid's l2: 32683.3
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 22111.1	valid's l2: 30127.2
# Early stopping, best iteration is:
# [63]	train's l2: 20812.5	valid's l2: 28558
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 22937.9	valid's l2: 20539.1
# [100]	train's l2: 18420.8	valid's l2: 16950.3
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 18420.8	valid's l2: 16950.3
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 23099.7	valid's l2: 20536.2
# Early stopping, best iteration is:
# [78]	train's l2: 20695.6	valid's l2: 19034.5
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 23297.9	valid's l2: 24284.5
# [100]	train's l2: 18888.8	valid's l2: 20536.5
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 18888.8	valid's l2: 20536.5
#
# ===== レタス モデルをKFold(5)で学習中 =====
# Fold 1/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 447243	valid's l2: 445886
# [100]	train's l2: 392356	valid's l2: 399908
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 392356	valid's l2: 399908
# Fold 2/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 439127	valid's l2: 435921
# [100]	train's l2: 386784	valid's l2: 395030
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 386784	valid's l2: 395030
# Fold 3/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 429939	valid's l2: 492289
# [100]	train's l2: 384111	valid's l2: 438853
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 384111	valid's l2: 438853
# Fold 4/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 441793	valid's l2: 429716
# [100]	train's l2: 386035	valid's l2: 370742
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 386035	valid's l2: 370742
# Fold 5/5
# Training until validation scores don't improve for 5 rounds
# [50]	train's l2: 432999	valid's l2: 442066
# [100]	train's l2: 383469	valid's l2: 399974
# Did not meet early stopping. Best iteration is:
# [100]	train's l2: 383469	valid's l2: 399974

# %%
models
# Out:
# {'いんげん': [<lightgbm.basic.Booster at 0x1bc7b03b5f0>,
#   <lightgbm.basic.Booster at 0x1bc7b038a70>,
#   <lightgbm.basic.Booster at 0x1bc7b038f80>,
#   <lightgbm.basic.Booster at 0x1bc7b039850>,
#   <lightgbm.basic.Booster at 0x1bc795b42f0>],
#  'うど': [<lightgbm.basic.Booster at 0x1bc795b6000>,
#   <lightgbm.basic.Booster at 0x1bc795b7830>,
#   <lightgbm.basic.Booster at 0x1bc78d9f290>,
#   <lightgbm.basic.Booster at 0x1bc78d9fdd0>,
#   <lightgbm.basic.Booster at 0x1bc77480da0>],
#  'うめ': [<lightgbm.basic.Booster at 0x1bc78d9ccb0>,
#   <lightgbm.basic.Booster at 0x1bc795b72c0>,
#   <lightgbm.basic.Booster at 0x1bc7b03bc80>,
#   <lightgbm.basic.Booster at 0x1bc7b038ec0>,
#   <lightgbm.basic.Booster at 0x1bc7743e9f0>],
#  'えだまめ': [<lightgbm.basic.Booster at 0x1bc7b03b110>,
#   <lightgbm.basic.Booster at 0x1bc7b039190>,
#   <lightgbm.basic.Booster at 0x1bc795b7d40>,
#   <lightgbm.basic.Booster at 0x1bc7b039be0>,
#   <lightgbm.basic.Booster at 0x1bc02702330>],
#  'えのきだけ': [<lightgbm.basic.Booster at 0x1bc7b038890>,
#   <lightgbm.basic.Booster at 0x1bc795b5df0>,
#   <lightgbm.basic.Booster at 0x1bc6e7a8290>,
#   <lightgbm.basic.Booster at 0x1bc02700da0>,
#   <lightgbm.basic.Booster at 0x1bc027011f0>],
#  'かぶ': [<lightgbm.basic.Booster at 0x1bc02701fa0>,
#   <lightgbm.basic.Booster at 0x1bc77480f20>,
#   <lightgbm.basic.Booster at 0x1bc02701010>,
#   <lightgbm.basic.Booster at 0x1bc02703ec0>,
#   <lightgbm.basic.Booster at 0x1bc02701cd0>],
#  'かぼちゃ': [<lightgbm.basic.Booster at 0x1bc027000b0>,
#   <lightgbm.basic.Booster at 0x1bc02703dd0>,
#   <lightgbm.basic.Booster at 0x1bc02703650>,
#   <lightgbm.basic.Booster at 0x1bc02703c50>,
#   <lightgbm.basic.Booster at 0x1bc02703d70>],
#  'きゅうり': [<lightgbm.basic.Booster at 0x1bc02700440>,
#   <lightgbm.basic.Booster at 0x1bc027027b0>,
#   <lightgbm.basic.Booster at 0x1bc02701670>,
#   <lightgbm.basic.Booster at 0x1bc78900dd0>,
#   <lightgbm.basic.Booster at 0x1bc02700170>],
#  'こまつな': [<lightgbm.basic.Booster at 0x1bc7b0999d0>,
#   <lightgbm.basic.Booster at 0x1bc7b0983b0>,
#   <lightgbm.basic.Booster at 0x1bc7b098f20>,
#   <lightgbm.basic.Booster at 0x1bc7b038c50>,
#   <lightgbm.basic.Booster at 0x1bc7b099580>],
#  'ごぼう': [<lightgbm.basic.Booster at 0x1bc7b03a720>,
#   <lightgbm.basic.Booster at 0x1bc02702240>,
#   <lightgbm.basic.Booster at 0x1bc7b09b470>,
#   <lightgbm.basic.Booster at 0x1bc7b09b590>,
#   <lightgbm.basic.Booster at 0x1bc7b03a900>],
#  'さつまいも': [<lightgbm.basic.Booster at 0x1bc02703da0>,
#   <lightgbm.basic.Booster at 0x1bc7b099010>,
#   <lightgbm.basic.Booster at 0x1bc7b099280>,
#   <lightgbm.basic.Booster at 0x1bc7b0987a0>,
#   <lightgbm.basic.Booster at 0x1bc7b098080>],
#  'さといも': [<lightgbm.basic.Booster at 0x1bc7b09b260>,
#   <lightgbm.basic.Booster at 0x1bc7b098650>,
#   <lightgbm.basic.Booster at 0x1bc7b09a930>,
#   <lightgbm.basic.Booster at 0x1bc7b09b770>,
#   <lightgbm.basic.Booster at 0x1bc7b09a990>],
#  'さやえんどう': [<lightgbm.basic.Booster at 0x1bc7b09ba10>,
#   <lightgbm.basic.Booster at 0x1bc7b099610>,
#   <lightgbm.basic.Booster at 0x1bc7b09a540>,
#   <lightgbm.basic.Booster at 0x1bc7b09b500>,
#   <lightgbm.basic.Booster at 0x1bc7b0981a0>],
#  'しめじ': [<lightgbm.basic.Booster at 0x1bc7b098530>,
#   <lightgbm.basic.Booster at 0x1bc7b09b620>,
#   <lightgbm.basic.Booster at 0x1bc7b0c8920>,
#   <lightgbm.basic.Booster at 0x1bc7b0c9910>,
#   <lightgbm.basic.Booster at 0x1bc7b0c90a0>],
#  'しゅんぎく': [<lightgbm.basic.Booster at 0x1bc7b0c8110>,
#   <lightgbm.basic.Booster at 0x1bc7b0c9f70>,
#   <lightgbm.basic.Booster at 0x1bc795b6d80>,
#   <lightgbm.basic.Booster at 0x1bc7b09bd70>,
#   <lightgbm.basic.Booster at 0x1bc02701a60>],
#  'じゃがいも': [<lightgbm.basic.Booster at 0x1bc7b09b230>,
#   <lightgbm.basic.Booster at 0x1bc7b0c9490>,
#   <lightgbm.basic.Booster at 0x1bc7b0ca630>,
#   <lightgbm.basic.Booster at 0x1bc7b0ca9f0>,
#   <lightgbm.basic.Booster at 0x1bc7b0caae0>],
#  'そらまめ': [<lightgbm.basic.Booster at 0x1bc7b0cbe30>,
#   <lightgbm.basic.Booster at 0x1bc7b0caed0>,
#   <lightgbm.basic.Booster at 0x1bc7b0c9e50>,
#   <lightgbm.basic.Booster at 0x1bc7b0ca6f0>,
#   <lightgbm.basic.Booster at 0x1bc7b0cbc80>],
#  'たけのこ': [<lightgbm.basic.Booster at 0x1bc7b0c9d90>,
#   <lightgbm.basic.Booster at 0x1bc7b0ca780>,
#   <lightgbm.basic.Booster at 0x1bc027024b0>,
#   <lightgbm.basic.Booster at 0x1bc7b0c89e0>,
#   <lightgbm.basic.Booster at 0x1bc7b09af60>],
#  'たまねぎ': [<lightgbm.basic.Booster at 0x1bc7b09a360>,
#   <lightgbm.basic.Booster at 0x1bc7b09a330>,
#   <lightgbm.basic.Booster at 0x1bc7b0393a0>,
#   <lightgbm.basic.Booster at 0x1bc7b0983e0>,
#   <lightgbm.basic.Booster at 0x1bc7b098b90>],
#  'だいこん': [<lightgbm.basic.Booster at 0x1bc7b098770>,
#   <lightgbm.basic.Booster at 0x1bc7b099460>,
#   <lightgbm.basic.Booster at 0x1bc7b099df0>,
#   <lightgbm.basic.Booster at 0x1bc7b039af0>,
#   <lightgbm.basic.Booster at 0x1bc7b099820>],
#  'とうもろこし': [<lightgbm.basic.Booster at 0x1bc7b03a360>,
#   <lightgbm.basic.Booster at 0x1bc7b03a1e0>,
#   <lightgbm.basic.Booster at 0x1bc7b099eb0>,
#   <lightgbm.basic.Booster at 0x1bc02701a00>,
#   <lightgbm.basic.Booster at 0x1bc02701910>],
#  'なす': [<lightgbm.basic.Booster at 0x1bc7b03a960>,
#   <lightgbm.basic.Booster at 0x1bc78d9c920>,
#   <lightgbm.basic.Booster at 0x1bc02702690>,
#   <lightgbm.basic.Booster at 0x1bc7b03a6f0>,
#   <lightgbm.basic.Booster at 0x1bc795b76b0>],
#  'なのはな': [<lightgbm.basic.Booster at 0x1bc78d9ee10>,
#   <lightgbm.basic.Booster at 0x1bc7b098da0>,
#   <lightgbm.basic.Booster at 0x1bc78d9fe60>,
#   <lightgbm.basic.Booster at 0x1bc02703a10>,
#   <lightgbm.basic.Booster at 0x1bc02700710>],
#  'なましいたけ': [<lightgbm.basic.Booster at 0x1bc7b03a8a0>,
#   <lightgbm.basic.Booster at 0x1bc795b5160>,
#   <lightgbm.basic.Booster at 0x1bc02703230>,
#   <lightgbm.basic.Booster at 0x1bc7b03a0c0>,
#   <lightgbm.basic.Booster at 0x1bc7b0c8560>],
#  'にら': [<lightgbm.basic.Booster at 0x1bc7b0cb950>,
#   <lightgbm.basic.Booster at 0x1bc7b03b8f0>,
#   <lightgbm.basic.Booster at 0x1bc7b0cb050>,
#   <lightgbm.basic.Booster at 0x1bc7b0c9100>,
#   <lightgbm.basic.Booster at 0x1bc7b0c9cd0>],
#  'にんじん': [<lightgbm.basic.Booster at 0x1bc02703a40>,
#   <lightgbm.basic.Booster at 0x1bc7b0cab10>,
#   <lightgbm.basic.Booster at 0x1bc7b09b890>,
#   <lightgbm.basic.Booster at 0x1bc7b0c93d0>,
#   <lightgbm.basic.Booster at 0x1bc7b098890>],
#  'ねぎ': [<lightgbm.basic.Booster at 0x1bc7b038710>,
#   <lightgbm.basic.Booster at 0x1bc7b0cbda0>,
#   <lightgbm.basic.Booster at 0x1bc7b0c8440>,
#   <lightgbm.basic.Booster at 0x1bc7b0cad80>,
#   <lightgbm.basic.Booster at 0x1bc7b098560>],
#  'はくさい': [<lightgbm.basic.Booster at 0x1bc7b0c8140>,
#   <lightgbm.basic.Booster at 0x1bc7b0ca750>,
#   <lightgbm.basic.Booster at 0x1bc02979550>,
#   <lightgbm.basic.Booster at 0x1bc02978c50>,
#   <lightgbm.basic.Booster at 0x1bc02979c40>],
#  'ふき': [<lightgbm.basic.Booster at 0x1bc02978620>,
#   <lightgbm.basic.Booster at 0x1bc7b09a420>,
#   <lightgbm.basic.Booster at 0x1bc02703aa0>,
#   <lightgbm.basic.Booster at 0x1bc7b0c8350>,
#   <lightgbm.basic.Booster at 0x1bc6e7a9520>],
#  'ほうれんそう': [<lightgbm.basic.Booster at 0x1bc78cc5790>,
#   <lightgbm.basic.Booster at 0x1bc0297b860>,
#   <lightgbm.basic.Booster at 0x1bc0297bd70>,
#   <lightgbm.basic.Booster at 0x1bc02979610>,
#   <lightgbm.basic.Booster at 0x1bc027007a0>],
#  'まつたけ': [<lightgbm.basic.Booster at 0x1bc02979cd0>,
#   <lightgbm.basic.Booster at 0x1bc0297bfb0>,
#   <lightgbm.basic.Booster at 0x1bc0297ad80>,
#   <lightgbm.basic.Booster at 0x1bc0297acf0>,
#   <lightgbm.basic.Booster at 0x1bc7b038500>],
#  'みずな': [<lightgbm.basic.Booster at 0x1bc0297b110>,
#   <lightgbm.basic.Booster at 0x1bc0297a2d0>,
#   <lightgbm.basic.Booster at 0x1bc02978830>,
#   <lightgbm.basic.Booster at 0x1bc02979a90>,
#   <lightgbm.basic.Booster at 0x1bc0297ac30>],
#  'れんこん': [<lightgbm.basic.Booster at 0x1bc02978d70>,
#   <lightgbm.basic.Booster at 0x1bc7b039820>,
#   <lightgbm.basic.Booster at 0x1bc77480b60>,
#   <lightgbm.basic.Booster at 0x1bc0297a6f0>,
#   <lightgbm.basic.Booster at 0x1bc7b09b7d0>],
#  'アスパラガス': [<lightgbm.basic.Booster at 0x1bc7b0c9370>,
#   <lightgbm.basic.Booster at 0x1bc7b03bcb0>,
#   <lightgbm.basic.Booster at 0x1bc04309c40>,
#   <lightgbm.basic.Booster at 0x1bc04309340>,
#   <lightgbm.basic.Booster at 0x1bc0430a6c0>],
#  'オクラ': [<lightgbm.basic.Booster at 0x1bc7b03adb0>,
#   <lightgbm.basic.Booster at 0x1bc043097f0>,
#   <lightgbm.basic.Booster at 0x1bc02702b70>,
#   <lightgbm.basic.Booster at 0x1bc7b0ca120>,
#   <lightgbm.basic.Booster at 0x1bc7b099910>],
#  'キャベツ': [<lightgbm.basic.Booster at 0x1bc0430ae10>,
#   <lightgbm.basic.Booster at 0x1bc04308890>,
#   <lightgbm.basic.Booster at 0x1bc7b09b440>,
#   <lightgbm.basic.Booster at 0x1bc0430afc0>,
#   <lightgbm.basic.Booster at 0x1bc0430ac60>],
#  'セルリー': [<lightgbm.basic.Booster at 0x1bc0430a5d0>,
#   <lightgbm.basic.Booster at 0x1bc0297a540>,
#   <lightgbm.basic.Booster at 0x1bc7b098e90>,
#   <lightgbm.basic.Booster at 0x1bc0430bec0>,
#   <lightgbm.basic.Booster at 0x1bc043094f0>],
#  'トマト': [<lightgbm.basic.Booster at 0x1bc0430bd40>,
#   <lightgbm.basic.Booster at 0x1bc0430a1b0>,
#   <lightgbm.basic.Booster at 0x1bc0430b7a0>,
#   <lightgbm.basic.Booster at 0x1bc0430b6b0>,
#   <lightgbm.basic.Booster at 0x1bc04308b30>],
#  'ピース': [<lightgbm.basic.Booster at 0x1bc0430bfe0>,
#   <lightgbm.basic.Booster at 0x1bc0430ac30>,
#   <lightgbm.basic.Booster at 0x1bc0297aba0>,
#   <lightgbm.basic.Booster at 0x1bc04309bb0>,
#   <lightgbm.basic.Booster at 0x1bc78d9e2d0>],
#  'ピーマン': [<lightgbm.basic.Booster at 0x1bc0430b2f0>,
#   <lightgbm.basic.Booster at 0x1bc7b09b8f0>,
#   <lightgbm.basic.Booster at 0x1bc0430a7b0>,
#   <lightgbm.basic.Booster at 0x1bc0430a930>,
#   <lightgbm.basic.Booster at 0x1bc7b099ac0>],
#  'ブロッコリー': [<lightgbm.basic.Booster at 0x1bc7b09b410>,
#   <lightgbm.basic.Booster at 0x1bc0439e540>,
#   <lightgbm.basic.Booster at 0x1bc0439e150>,
#   <lightgbm.basic.Booster at 0x1bc7b0c99d0>,
#   <lightgbm.basic.Booster at 0x1bc0439e8d0>],
#  'ミニトマト': [<lightgbm.basic.Booster at 0x1bc0439fd10>,
#   <lightgbm.basic.Booster at 0x1bc0430b260>,
#   <lightgbm.basic.Booster at 0x1bc0439e750>,
#   <lightgbm.basic.Booster at 0x1bc0439d7f0>,
#   <lightgbm.basic.Booster at 0x1bc0430ae70>],
#  'レイシにがうり': [<lightgbm.basic.Booster at 0x1bc0439e0c0>,
#   <lightgbm.basic.Booster at 0x1bc0439fad0>,
#   <lightgbm.basic.Booster at 0x1bc795b77a0>,
#   <lightgbm.basic.Booster at 0x1bc0439f320>,
#   <lightgbm.basic.Booster at 0x1bc04309280>],
#  'レタス': [<lightgbm.basic.Booster at 0x1bc0439f560>,
#   <lightgbm.basic.Booster at 0x1bc04309010>,
#   <lightgbm.basic.Booster at 0x1bc0439c200>,
#   <lightgbm.basic.Booster at 0x1bc0439d310>,
#   <lightgbm.basic.Booster at 0x1bc0439fd40>]}

# %%
import numpy as np

pred_list = []

for kd, group in test_df.groupby("kind"):

    fold_models = models[kd]  # ← foldモデルが複数入っている
    X_test = group.copy()

    # 全 fold モデルの予測を行い平均
    fold_pred = np.mean([m.predict(X_test) for m in fold_models], axis=0)

    X_test["mode_price"] = fold_pred
    pred_list.append(X_test)

# まとめ・並び順合わせ
result = pd.concat(pred_list).sort_index()

# 日付整形（year,month,day → YYYYMMDD）
result["date"] = (
    result["year"].astype(str)
    + result["month"].astype(str).str.zfill(2)
    + result["day"].astype(str).str.zfill(2)
)
result["date"] = result["date"].astype(int)

# 提出形式に整形
submit = result[["kind", "date", "mode_price"]]
submit.to_csv("submit.csv", index=False)

submit
# Out:
# C:\Users\ND013\AppData\Local\Temp\ipykernel_24764\1180845613.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for kd, group in test_df.groupby("kind"):
#       kind      date   mode_price
# 0     だいこん  20220502  1010.021288
# 1     だいこん  20220502  1013.745020
# 2     だいこん  20220502  1068.050285
# 3     だいこん  20220506  1009.253255
# 4     だいこん  20220506  1012.976988
# ..     ...       ...          ...
# 815  ミニトマト  20220528   102.058406
# 816  ミニトマト  20220530   104.543056
# 817  ミニトマト  20220530   102.285645
# 818  ミニトマト  20220531   105.797430
# 819  ミニトマト  20220531   103.540019
#
# [820 rows x 3 columns]

# %%
submit_mean = (
    submit.groupby(["kind", "date"], as_index=False)["mode_price"]
          .mean()
)
# ① area 側の kind の出現順を取得
kind_order = test_df["kind"].drop_duplicates().tolist()

# ② price 側の kind を Categorical に変換して順序を固定
submit_mean["kind"] = pd.Categorical(submit_mean["kind"], categories=kind_order, ordered=True)

# ③ 並び替え
df_price_sorted = submit_mean.sort_values(["kind", "date"]).reset_index(drop=True)
# Out:
# C:\Users\ND013\AppData\Local\Temp\ipykernel_24764\975664683.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   submit.groupby(["kind", "date"], as_index=False)["mode_price"]

# %%
df_price_sorted.to_csv("submit.csv", index=False)
df_price_sorted
# Out:
#       kind      date   mode_price
# 0     だいこん  20220502  1030.605531
# 1     だいこん  20220506  1030.093509
# 2     だいこん  20220507  1027.672622
# 3     だいこん  20220509  1026.700236
# 4     だいこん  20220510  1026.700236
# ..     ...       ...          ...
# 315  ミニトマト  20220526   103.010743
# 316  ミニトマト  20220527   103.010743
# 317  ミニトマト  20220528   103.187111
# 318  ミニトマト  20220530   103.414351
# 319  ミニトマト  20220531   104.668724
#
# [320 rows x 3 columns]
